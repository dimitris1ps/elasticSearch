# %%
#from datetime import datetime
#!pip install elasticsearch --user
from elasticsearch import Elasticsearch
#!pip install python-greeklish --user
from greeklish.converter import Converter
import pandas as pd

# %%
# create an object for greeklish translation
conv = Converter(max_expansions=1)

# %%
# read the file with the spitishop products and their details
df_products = pd.read_pickle('data/df_products.pkl')

# %%
# create a column with the title having changed some letters based on greek_letters_dict
greek_letters_dict = {'ω':'ο'}
df_products['Product_name2'] = df_products.apply(lambda x: x["Product_name"].lower().translate(str.maketrans(greek_letters_dict)), axis=1)

# create a column with the greeklish title
df_products['Product_name_eng'] = df_products.apply(lambda x: conv.convert(x["Product_name2"])[0], axis=1)

# keep only specific columns
df_products = df_products[['Code', 'Price', 'Product_name', 'Url', 'Brand', 'Product_name_eng', 'name', 'img_url', 'freq']]

# drop rows with nans
df_products = df_products.dropna()

# drop duplicates
df_products = df_products.drop_duplicates(subset=['Code'], keep='first')

# %%
df_products.head(2)
# Out:
#     Code  Price                        Product_name  \
# 0  29866   59.0  Μπουρνούζι Guy Laroche Linda Lilac
# 1  29868   59.0    Μπουρνούζι Guy Laroche Linda Red
#
#                                                  Url        Brand  \
# 0  https://www.spitishop.gr/μπουρνούζι-guy-laroch...  Guy Laroche
# 1  https://www.spitishop.gr/μπουρνούζι-guy-laroch...  Guy Laroche
#
#                      Product_name_eng    name  \
# 0  mpournouzi guy laroche linda lilac  Μπάνιο
# 1    mpournouzi guy laroche linda red  Μπάνιο
#
#                                              img_url  freq
# 0  https://www.spitishop.gr/26083/μπουρνούζι-guy-...  11.0
# 1  https://www.spitishop.gr/26085/μπουρνούζι-guy-...   9.0

# %%
df_products.name.unique()
# Out:
# array(['Μπάνιο', 'Παιδικά', 'Κρεβατοκάμαρα', 'Βρεφικά', 'Σαλόνι',
#        'Κουζίνα - Τραπεζαρία', 'Μόδα Γάμου', 'Θαλάσσης', 'Διακόσμηση',
#        'Χριστουγεννιάτικα', 'Κουρτίνες', 'Χαλιά', 'Προώθηση', 'Κήπος'],
#       dtype=object)

# %%
df_products.shape
# Out:
# (15050, 9)

# %%
# create a list of dicts with the product details
products = []
tmp = df_products.apply(lambda x: products.append({'title_eng':x['Product_name_eng'],
                                                         'title_init':x['Product_name'],
                                                         'url':x['Url'],
                                                         'Price':x['Price'],
                                                         'Brand':x['Brand'],
                                                         'Category':x['name'],
                                                         'img_url':x['img_url'],
                                                         'Code':x['Code'],
                                                         'Popularity':x['freq']
                                                  }), axis=1)

# %%
# connect to elasticsearch / create an Elasticsearch object

# create an Elasticsearch object
#es = Elasticsearch()

def connect_elasticsearch():
    _es = None
    #_es = Elasticsearch([{'host': 'localhost', 'port': 9200}])
    _es = Elasticsearch()
    if _es.ping():
        print('- Connected')
    else:
        print('- Problem with the connection')
    return _es

es = connect_elasticsearch()
# Out:
# - Connected

# %%
def create_index(es_object, index_name='dimostest1'):
    
    # index settings
#     settings = {
#           "settings": {
#             "analysis": {
#               "analyzer": {
#                 "my_analyzer": { 
#                   "type": "standard", # https://www.elastic.co/guide/en/elasticsearch/reference/current/analysis-standard-analyzer.html
#                   "stopwords": ["sentoni", "the", 'mpournouzi'],
#                   #"stopwords_path": "stopwords/my_stopwords.txt"
#                 }
#               }
#             }
#           },
#         #"mappings": {}
#     }

    # https://www.elastic.co/guide/en/elasticsearch/reference/current/analysis-synonym-tokenfilter.html
    settings = {
                "settings": {
                    "index" : {
                        "analysis" : {
                            "analyzer" : {
                                "my_analyzer" : {
                                    "tokenizer" : "standard",
                                    "filter" : ["my_stop", "synonym"]
                                }
                            },
                            "filter" : {
                                "my_stop": {
                                    "type" : "stop",
                                    "stopwords": ["to", "kai"]
                                },
                                "synonym" : {
                                    "type" : "synonym",
                                    "lenient": True,
                                    "synonyms" : ["ypnodomatio, bedroom => krebatokamara"]
                                }
                            }
                        }
                    }
                }
            }
    
    try:
        #if not es_object.indices.exists(index_name):
        # Ignore 400 means to ignore "Index Already Exist" error.
        es_object.indices.create(index=index_name, ignore=400, body=settings)
        print('Created Index')
    except Exception as ex:
        print('Error: ', str(ex))

create_index(es, 'dimostest1')
# Out:
# Created Index

# %%
# settings = {
#                 "settings": {
#                     "index" : {
#                         "analysis" : {
#                             "analyzer" : {
#                                 "synonym" : {
#                                     "tokenizer" : "standard",
#                                     "filter" : ["my_stop", "synonym"]
#                                 }
#                             },
#                             "filter" : {
#                                 "my_stop": {
#                                     "type" : "stop",
#                                     "stopwords": ["sentoni", "the", 'mpournouzi']
#                                 },
#                                 "synonym" : {
#                                     "type" : "synonym",
#                                     "lenient": True,
#                                     "synonyms" : ["foo, bar => baz"]
#                                 }
#                             }
#                         }
#                     }
#                 }
#             }


# es.indices.create(index='dimostest1', ignore=400, body=settings)

# %%
# check if the index exists
es.indices.exists('dimostest1')
# Out:
# True

# %%
# delete the index
#es.indices.delete(index='dimostest1', ignore=[400, 404])

# %%
es.indices.get_mapping(index='dimostest1')
# Out:
# {'dimostest1': {'mappings': {'properties': {'Category': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#     'Code': {'type': 'long'},
#     'Popularity': {'type': 'float'},
#     'Price': {'type': 'float'},
#     'title_eng': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#     'title_init': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}}}}}}

# %%
# add products to the index
i = 1
for product in products[0:]:
    es.index(index='dimostest1',
             doc_type='product',
             id=i,
             body=product,
            )
    i += 1

# %%
#delete a product from the index
#es.delete(index='dimostest1', doc_type='product', id=1)

# %%
# get a document based on its id
res=es.get(index='dimostest1',doc_type='product',id=2)
res
# Out:
# {'_index': 'dimostest1',
#  '_type': 'product',
#  '_id': '2',
#  '_version': 1,
#  '_seq_no': 1,
#  '_primary_term': 1,
#  'found': True,
#  '_source': {'title_eng': 'mpournouzi guy laroche linda red',
#   'title_init': 'Μπουρνούζι Guy Laroche Linda Red',
#   'url': 'https://www.spitishop.gr/μπουρνούζι-guy-laroche-linda-red-29868.html',
#   'Price': 59.0,
#   'Brand': 'Guy Laroche',
#   'Category': 'Μπάνιο',
#   'img_url': 'https://www.spitishop.gr/26085/μπουρνούζι-guy-laroche-linda-red.jpg',
#   'Code': 29868,
#   'Popularity': 9.0}}

# %%
# https://www.elastic.co/guide/en/elasticsearch/reference/current/index.html

# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-match-query.html

# %%
# settings = {
#       "settings": {
#         "analysis": {
#           "analyzer": {
#             "my_analyzer": { 
#               "type": "standard", 
#                 "stopwords": ["sentoni", "the", 'mpournouzi']
#             }
#           }
#         }
#       },
#     #"mappings": {}
# }

# %%
# settings = {
#     "settings": {
#         "index" : {
#             "analysis" : {
#                 "analyzer" : {
#                     "synonym" : {
#                         "tokenizer" : "standard",
#                         "filter" : ["my_stop", "synonym"]
#                     }
#                 },
#                 "filter" : {
#                     "my_stop": {
#                         "type" : "stop",
#                         "stopwords": ["sentoni", "the", 'mpournouzi']
#                     },
#                     "synonym" : {
#                         "type" : "synonym",
#                         "lenient": True,
#                         "synonyms" : ["kouvertatatatata, keftedoperda => kouberta"]
#                     }
#                 }
#             }
#         }
#     }
# }

# %%
def get_results(query, category):
    
    if query.isdigit():
        print('- You are searching a product code')
        df_product = df_products[df_products.Code==int(query)]
        
        if len(df_product)>0:
            print('-- The product code was found')
            results = [{'_score': 100,
                             '_source': {'Brand': df_product.iloc[0]['Brand'],
                                          'Category': df_product.iloc[0]['name'],
                                          'Code': df_product.iloc[0]['Code'],
                                          'Price': df_product.iloc[0]['Price'],
                                          'img_url': df_product.iloc[0]['img_url'],
                                          'title_eng': df_product.iloc[0]['Product_name_eng'],
                                          'title_init': df_product.iloc[0]['Product_name'],
                                          'url': df_product.iloc[0]['Url'],
                                        'Popularity': df_product.iloc[0]['freq']}}]
            return results
            
    
    # convert the query to lowercase and some letters based on greek_letters_dict
    query = query.lower().translate(str.maketrans(greek_letters_dict))
    # convert it to greeklish
    query = conv.convert(query)[0]
    print(query)
                                    
    # search_flag defines whether the results are procuced by elasticsearch or based on popularity
    search_flag = 0 
    
    # search the index based on the query    
    if category=='All':
        # search the index based on the query
        results = es.search(index='dimostest1', body = { "from" : 0, "size" : 1000,
            'query':{
                'bool': {
                  'must': [
                                {'match':{'title_eng':{"query" : query,
                                                       "fuzziness": "AUTO:3,5", # https://www.elastic.co/guide/en/elasticsearch/reference/current/common-options.html#fuzziness
                                                       #"fuzziness": 2,
                                                       #"fuzzy_transpositions":False,
                                                        "analyzer": "my_analyzer"

                                                      }}},
                                #{'match': {'Category': category}},
                           ],
#                   "filter": [ 
#                                 {"term":{"Category":category}},
#                             ]
                    
                }
            }
        },                  
                           )
    else:
        results = es.search(index='dimostest1', body = { "from" : 0, "size" : 1000,
            'query':{
                'bool': {
                  'must': [
                                {'match':{'title_eng':{"query" : query,
                                                       "fuzziness": "AUTO:3,5", # https://www.elastic.co/guide/en/elasticsearch/reference/current/common-options.html#fuzziness
                                                       #"fuzziness": 2,
                                                       #"fuzzy_transpositions":False,
                                                        "analyzer": "my_analyzer"

                                                      }}},
                                {'match': {'Category': category}},
                           ],
#                   "filter": [ 
#                                 {"term":{"Category":category}},
#                             ]
                    
                }
            }
        },                  
                           )

    # list of results
    results = results['hits']['hits'][0:]
    
    #print(results)

#     results2 = []
#     results2.append(results[0:5])
#     results2.append(results[5:10])
#     results2.append(results[10:15])
#     results2.append(results[15:20])
#     results2.append(results[20:25])
#     results2.append(results[25:30])
    
    #print(results2[0][0])
    
    # if the search query doesnt have resutls in the specified category, then check in all categories
    if (len(results)==0) & (category!='All'):
        print(' - Searching regardless the specified category')
        results = es.search(index='dimostest1', body = { "from" : 0, "size" : 1000,
            'query':{
                'bool': {
                  'must': [
                                {'match':{'title_eng':{"query" : query,
                                                       "fuzziness": "AUTO:3,5", # https://www.elastic.co/guide/en/elasticsearch/reference/current/common-options.html#fuzziness
                                                       #"fuzziness": 2,
                                                       #"fuzzy_transpositions":False,
                                                        "analyzer": "my_analyzer"

                                                      }}},
                                #{'match': {'Category': category}},
                           ],
#                   "filter": [ 
#                                 {"term":{"Category":category}},
#                             ]
                    
                }
            }
        },                  
                           )
        results = results['hits']['hits'][0:]
    
    return results

# %%
query = 'sdfg'
# convert it to greeklish and lowercase
#query = conv.convert(query)[0].lower()
category = 'All'

print('- Searching for: "', query, '" in the category: "', category, '".')
res = get_results(query, category)

print('- ', len(res), ' results were returned.')
# Out:
# - Searching for: " sdfg " in the category: " All ".
# sdfg
# -  0  results were returned.

# %%
df_products.head(2)
# Out:
#     Code  Price                        Product_name  \
# 0  29866   59.0  Μπουρνούζι Guy Laroche Linda Lilac
# 1  29868   59.0    Μπουρνούζι Guy Laroche Linda Red
#
#                                                  Url        Brand  \
# 0  https://www.spitishop.gr/μπουρνούζι-guy-laroch...  Guy Laroche
# 1  https://www.spitishop.gr/μπουρνούζι-guy-laroch...  Guy Laroche
#
#                      Product_name_eng    name  \
# 0  mpournouzi guy laroche linda lilac  Μπάνιο
# 1    mpournouzi guy laroche linda red  Μπάνιο
#
#                                              img_url  freq
# 0  https://www.spitishop.gr/26083/μπουρνούζι-guy-...  11.0
# 1  https://www.spitishop.gr/26085/μπουρνούζι-guy-...   9.0

# %%
res[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-45e58e558557> in <module>()
# ----> 1 res[0]
#
# IndexError: list index out of range

# %%
results = []
for i in range(len(res)):
    #print(res[i]['_source']['title_init']+' - ', res[i]['_source']['Price'])
    result = res[i]
    
    results.append({
        'Code':result['_source']['Code'],
        'Product_name':result['_source']['title_init'],
                   'title_eng':result['_source']['title_eng'],
                    'Category':result['_source']['Category'],
                    'Price':result['_source']['Price'],
                    'score':result['_score'],
                    'img_url':result['_source']['img_url'],
                    'Url':result['_source']['url'],
                    'Popularity':result['_source']['Popularity'],
                   })
    
df_results = pd.DataFrame(results)

if len(df_results) > 0:
    # convert list of dicts to pandas dataframe 
    #df_results = pd.DataFrame(results)
    
    # keep only results with relevance score higher that 4
    #df_results = df_results[df_results.score>4]
    
    # sort results based on relevance and Price/popularity
    df_results = df_results.sort_values(by=['score', 'Popularity'], ascending=[False, False])
    
    # search_flag defines whether the results are procuced by elasticsearch or based on popularity
    search_flag = 0

if len(df_results) == 0:
    print('- No results were returned via elasticsearch. So, return popular products.')
    df_results = df_products.sort_values(by=['freq'], ascending=[False]).head(30)
    #df_results = df_results[['Category', 'Price', 'title_eng', 'title_init']]
    
    # set the flag==1 - the resutls are produced based on popularity
    search_flag = 1
    
print(search_flag)
# Out:
# - No results were returned via elasticsearch. So, return popular products.
# 1

# %%
df_results
# Out:
#           Category    Code  Popularity   Price  \
# 0    Κρεβατοκάμαρα   77533        17.0   34.20
# 1    Κρεβατοκάμαρα   77534        10.0   45.00
# 8          Βρεφικά  126971         3.0   35.70
# 5          Βρεφικά  113958         2.0   35.70
# 6          Βρεφικά  114416         1.0   35.70
# 7          Βρεφικά  114554         1.0   35.70
# 2          Βρεφικά   53120         0.0   33.15
# 3          Βρεφικά   37647         0.0   28.70
# 4          Βρεφικά  103024         0.0   35.70
# 32   Κρεβατοκάμαρα   31749        21.0   35.10
# 33   Κρεβατοκάμαρα   31750        17.0   48.60
# 30   Κρεβατοκάμαρα   31725        14.0   52.20
# 42         Βρεφικά   91434        11.0   34.65
# 57         Βρεφικά  114420         9.0   32.76
# 14   Κρεβατοκάμαρα   75897         8.0   73.02
# 15         Βρεφικά   76979         7.0   26.10
# 31   Κρεβατοκάμαρα   31726         7.0   71.10
# 36   Κρεβατοκάμαρα   79850         7.0   29.75
# 37   Κρεβατοκάμαρα  100336         6.0   45.90
# 41         Βρεφικά   91429         5.0   34.65
# 56         Βρεφικά  114419         5.0   32.76
# 18   Κρεβατοκάμαρα   47264         4.0   33.60
# 19   Κρεβατοκάμαρα   47265         4.0   43.26
# 34   Κρεβατοκάμαρα   33094         4.0   54.00
# 38   Κρεβατοκάμαρα  100337         4.0   60.30
# 53   Κρεβατοκάμαρα  114063         4.0  144.48
# 55         Βρεφικά  114418         3.0   32.76
# 28   Κρεβατοκάμαρα   43049         2.0   67.15
# 45         Παιδικά  101291         2.0   62.16
# 50         Βρεφικά  113577         2.0   32.76
# ..             ...     ...         ...     ...
# 605  Κρεβατοκάμαρα  121991        64.0   79.50
# 591  Κρεβατοκάμαρα   36921        39.0   73.10
# 597  Κρεβατοκάμαρα   82587        28.0  125.00
# 606  Κρεβατοκάμαρα  121992        28.0   79.50
# 594  Κρεβατοκάμαρα   39136        27.0   50.15
# 607  Κρεβατοκάμαρα  121993        22.0   79.50
# 613  Κρεβατοκάμαρα  122002        21.0   84.50
# 600  Κρεβατοκάμαρα   82742        20.0  125.00
# 598  Κρεβατοκάμαρα   82740        18.0   89.54
# 618  Κρεβατοκάμαρα  130415        18.0  120.15
# 612  Κρεβατοκάμαρα  122001        12.0   84.50
# 599  Κρεβατοκάμαρα   82741         8.0   89.54
# 604        Βρεφικά  119917         7.0   24.15
# 614  Κρεβατοκάμαρα  122401         6.0  400.50
# 602  Κρεβατοκάμαρα  100341         5.0  103.50
# 609  Κρεβατοκάμαρα  121996         4.0   64.50
# 610  Κρεβατοκάμαρα  121999         4.0   69.50
# 616  Κρεβατοκάμαρα  129941         4.0  122.82
# 617  Κρεβατοκάμαρα  130410         4.0   93.45
# 593  Κρεβατοκάμαρα   39077         3.0  287.20
# 601  Κρεβατοκάμαρα   99049         2.0  185.00
# 615  Κρεβατοκάμαρα  122593         2.0   48.60
# 592  Κρεβατοκάμαρα   39076         1.0  220.15
# 595  Κρεβατοκάμαρα   39207         1.0   87.75
# 603        Βρεφικά   91664         1.0   34.00
# 611  Κρεβατοκάμαρα  122000         1.0   69.50
# 596  Κρεβατοκάμαρα   31844         0.0  261.00
# 621  Κρεβατοκάμαρα  130416        17.0  139.73
# 619  Κρεβατοκάμαρα   95961         1.0  175.50
# 620  Κρεβατοκάμαρα   95962         0.0  243.00
#
#                                           Product_name  \
# 0                            Πάπλωμα Μονό Nima Balance
# 1                       Πάπλωμα Υπέρδιπλο Nima Balance
# 8                         Πάπλωμα Κούνιας Rythmos Hope
# 5                       Πάπλωμα Κούνιας Rythmos Flying
# 6                         Πάπλωμα Κούνιας Rythmos Malo
# 7                     Πάπλωμα Κούνιας Rythmos Elefante
# 2                       Πάπλωμα Κούνιας Viopros Πάτρικ
# 3                       Πάπλωμα Κούνιας Viopros Αντζέλ
# 4                       Πάπλωμα Κούνιας Rythmos Nautic
# 32                    Πάπλωμα Μονό Nef-Nef Hollowfiber
# 33               Πάπλωμα Υπέρδιπλο Nef-Nef Hollowfiber
# 30                     Πάπλωμα Μονό Nef-Nef Microfiber
# 42                 Πάπλωμα Κούνιας Dimcol Αερόστατο 01
# 57                 Πάπλωμα Κούνιας Rythmos Paint Spots
# 14                   Πάπλωμα Υπέρδιπλο Sb Home Couette
# 15                    Πάπλωμα Κούνιας Nima Baby Beetle
# 31                Πάπλωμα Υπέρδιπλο Nef-Nef Microfiber
# 36                     Πάπλωμα Μονό (Σετ) Viopros 5230
# 37            Πάπλωμα Μονό Palamaiki Stripe Microfiber
# 41                       Πάπλωμα Κούνιας Dimcol Car 29
# 56                   Πάπλωμα Κούνιας Rythmos Tiny Pink
# 18                   Πάπλωμα Μονό Vesta Olympus 300gsm
# 19              Πάπλωμα Υπέρδιπλο Vesta Olympus 300gsm
# 34                        Πάπλωμα Μονό Nima Super Soft
# 38       Πάπλωμα Υπέρδιπλο Palamaiki Stripe Microfiber
# 53              Πάπλωμα Μάλλινο Υπέρδιπλο Rythmos Wool
# 55                   Πάπλωμα Κούνιας Rythmos Tiny Blue
# 28                      Πάπλωμα Μονό Anna Riska Luxury
# 45                    Πάπλωμα Μονό (Σετ) Rythmos Score
# 50                Πάπλωμα Κούνιας Rythmos Balloon Pink
# ..                                                 ...
# 605  Πάπλωμα + Σεντόνια Υπέρδιπλα (Σετ) Das Home Wi...
# 591  Πάπλωμα Φτερό - Πούπουλο Υπέρδιπλο Viopros Fea...
# 597  Πάπλωμα Πουπουλένιο Υπέρδιπλο Palamaiki 50/50 ...
# 606  Πάπλωμα + Σεντόνια Υπέρδιπλα (Σετ) Das Home Wi...
# 594  Πάπλωμα Φτερό - Πούπουλο Μονό Viopros Feather ...
# 607  Πάπλωμα + Σεντόνια Υπέρδιπλα (Σετ) Das Home Wi...
# 613  Πάπλωμα + Σεντόνια Υπέρδιπλα (Σετ) Das Home Wi...
# 600  Πάπλωμα Πουπουλένιο Υπέρδιπλο Palamaiki 50/50 ...
# 598  Πάπλωμα Πουπουλένιο Μονό Palamaiki 50/50 Aloe ...
# 618  Πάπλωμα Πουπουλένιο Υπέρδιπλο La Luna White Du...
# 612  Πάπλωμα + Σεντόνια Υπέρδιπλα (Σετ) Das Home Wi...
# 599  Πάπλωμα Πουπουλένιο Μονό Palamaiki 50/50 Aloe ...
# 604          Πάπλωμα Κούνιας Nef-Nef A Day At The Park
# 614  Πάπλωμα Πουπουλένιο King Size Polo Club Premiu...
# 602  Πάπλωμα King Size 4 Εποχών Palamaiki Twin Stri...
# 609  Πάπλωμα + Σεντόνια Μονά (Σετ) Das Home Winter ...
# 610  Πάπλωμα + Σεντόνια Μονά (Σετ) Das Home Winter ...
# 616  Πάπλωμα Μάλλινο King Size La Luna Wool Natural...
# 617  Πάπλωμα Πουπουλένιο Μονό La Luna White Duvet 8...
# 593  Πάπλωμα Πουπουλένιο Υπέρδιπλο Anna Riska 4 Επο...
# 601  Πάπλωμα 4 Εποχών King Size Kentia Accessories ...
# 615  Πάπλωμα Υπέρδιπλο 2 Όψεων Nima Bed Linen Abalo...
# 592  Πάπλωμα Πουπουλένιο Μονό Anna Riska 4 Εποχών 9...
# 595    Πάπλωμα Μονό Down Town Damas Salmon Primo S 426
# 603  Πάπλωμα Κούνιας Κόσμος Του Μωρού 7959 Hard Day...
# 611  Πάπλωμα + Σεντόνια Μονά (Σετ) Das Home Winter ...
# 596  Πάπλωμα Πουπουλένιο Μονό Nef-Nef White Goose D...
# 621  Πάπλωμα Πουπουλένιο King Size La Luna White Du...
# 619  Πάπλωμα Πουπουλένιο Μονό Nef-Nef White Duck Do...
# 620  Πάπλωμα Πουπουλένιο Υπέρδιπλο Nef-Nef White Du...
#
#                                                    Url  \
# 0    https://www.spitishop.gr/πάπλωμα-μονό-nima-bal...
# 1    https://www.spitishop.gr/πάπλωμα-υπέρδιπλο-nim...
# 8    https://www.spitishop.gr/πάπλωμα-κούνιας-rythm...
# 5    https://www.spitishop.gr/πάπλωμα-κούνιας-rythm...
# 6    https://www.spitishop.gr/πάπλωμα-κούνιας-rythm...
# 7    https://www.spitishop.gr/πάπλωμα-κούνιας-rythm...
# 2    https://www.spitishop.gr/πάπλωμα-κούνιας-viopr...
# 3    https://www.spitishop.gr/πάπλωμα-κούνιας-viopr...
# 4    https://www.spitishop.gr/πάπλωμα-κούνιας-rythm...
# 32   https://www.spitishop.gr/πάπλωμα-μονό-nef-nef-...
# 33   https://www.spitishop.gr/πάπλωμα-υπέρδιπλο-nef...
# 30   https://www.spitishop.gr/πάπλωμα-μονό-nef-nef-...
# 42   https://www.spitishop.gr/πάπλωμα-κούνιας-dimco...
# 57   https://www.spitishop.gr/πάπλωμα-κούνιας-rythm...
# 14   https://www.spitishop.gr/πάπλωμα-υπέρδιπλο-sb-...
# 15   https://www.spitishop.gr/πάπλωμα-κούνιας-nima-...
# 31   https://www.spitishop.gr/πάπλωμα-υπέρδιπλο-nef...
# 36   https://www.spitishop.gr/πάπλωμα-μονό-σετ-viop...
# 37   https://www.spitishop.gr/πάπλωμα-μονό-palamaik...
# 41   https://www.spitishop.gr/πάπλωμα-κούνιας-dimco...
# 56   https://www.spitishop.gr/πάπλωμα-κούνιας-rythm...
# 18   https://www.spitishop.gr/πάπλωμα-μονό-vesta-ol...
# 19   https://www.spitishop.gr/πάπλωμα-υπέρδιπλο-ves...
# 34   https://www.spitishop.gr/πάπλωμα-μονό-nima-sup...
# 38   https://www.spitishop.gr/πάπλωμα-υπέρδιπλο-pal...
# 53   https://www.spitishop.gr/πάπλωμα-μάλλινο-υπέρδ...
# 55   https://www.spitishop.gr/πάπλωμα-κούνιας-rythm...
# 28   https://www.spitishop.gr/πάπλωμα-μονό-anna-ris...
# 45   https://www.spitishop.gr/πάπλωμα-μονό-σετ-ryth...
# 50   https://www.spitishop.gr/πάπλωμα-κούνιας-rythm...
# ..                                                 ...
# 605  https://www.spitishop.gr/πάπλωμα-σεντόνια-υπέρ...
# 591  https://www.spitishop.gr/πάπλωμα-φτερό-πούπουλ...
# 597  https://www.spitishop.gr/πάπλωμα-πουπουλένιο-υ...
# 606  https://www.spitishop.gr/πάπλωμα-σεντόνια-υπέρ...
# 594  https://www.spitishop.gr/πάπλωμα-φτερό-πούπουλ...
# 607  https://www.spitishop.gr/πάπλωμα-σεντόνια-υπέρ...
# 613  https://www.spitishop.gr/πάπλωμα-σεντόνια-υπέρ...
# 600  https://www.spitishop.gr/πάπλωμα-πουπουλένιο-υ...
# 598  https://www.spitishop.gr/πάπλωμα-πουπουλένιο-μ...
# 618  https://www.spitishop.gr/πάπλωμα-πουπουλένιο-υ...
# 612  https://www.spitishop.gr/πάπλωμα-σεντόνια-υπέρ...
# 599  https://www.spitishop.gr/πάπλωμα-πουπουλένιο-μ...
# 604  https://www.spitishop.gr/πάπλωμα-κούνιας-nef-n...
# 614  https://www.spitishop.gr/πάπλωμα-πουπουλένιο-k...
# 602  https://www.spitishop.gr/πάπλωμα-king-size-4-ε...
# 609  https://www.spitishop.gr/πάπλωμα-σεντόνια-μονά...
# 610  https://www.spitishop.gr/πάπλωμα-σεντόνια-μονά...
# 616  https://www.spitishop.gr/πάπλωμα-μάλλινο-king-...
# 617  https://www.spitishop.gr/πάπλωμα-πουπουλένιο-μ...
# 593  https://www.spitishop.gr/πάπλωμα-πουπουλένιο-υ...
# 601  https://www.spitishop.gr/πάπλωμα-4-εποχών-king...
# 615  https://www.spitishop.gr/πάπλωμα-υπέρδιπλο-2-ό...
# 592  https://www.spitishop.gr/πάπλωμα-πουπουλένιο-μ...
# 595  https://www.spitishop.gr/πάπλωμα-μονό-down-tow...
# 603  https://www.spitishop.gr/πάπλωμα-κούνιας-κόσμο...
# 611  https://www.spitishop.gr/πάπλωμα-σεντόνια-μονά...
# 596  https://www.spitishop.gr/πάπλωμα-πουπουλένιο-μ...
# 621  https://www.spitishop.gr/πάπλωμα-πουπουλένιο-k...
# 619  https://www.spitishop.gr/πάπλωμα-πουπουλένιο-μ...
# 620  https://www.spitishop.gr/πάπλωμα-πουπουλένιο-υ...
#
#                                                img_url     score  \
# 0    https://www.spitishop.gr/223885/πάπλωμα-μονό-n...  2.737326
# 1    https://www.spitishop.gr/223886/πάπλωμα-υπέρδι...  2.737326
# 8    https://www.spitishop.gr/235468/πάπλωμα-κούνια...  2.737326
# 5    https://www.spitishop.gr/190617/πάπλωμα-κούνια...  2.737326
# 6    https://www.spitishop.gr/191550/πάπλωμα-κούνια...  2.737326
# 7    https://www.spitishop.gr/191801/πάπλωμα-κούνια...  2.737326
# 2    https://www.spitishop.gr/58615/πάπλωμα-κούνιας...  2.737326
# 3    https://www.spitishop.gr/37909/πάπλωμα-κούνιας...  2.737326
# 4    https://www.spitishop.gr/164583/πάπλωμα-κούνια...  2.737326
# 32   https://www.spitishop.gr/97842/πάπλωμα-μονό-ne...  2.552816
# 33   https://www.spitishop.gr/97845/πάπλωμα-υπέρδιπ...  2.552816
# 30   https://www.spitishop.gr/97801/πάπλωμα-μονό-ne...  2.552816
# 42   https://www.spitishop.gr/126473/πάπλωμα-κούνια...  2.552816
# 57   https://www.spitishop.gr/191554/πάπλωμα-κούνια...  2.552816
# 14   https://www.spitishop.gr/98357/πάπλωμα-υπέρδιπ...  2.552816
# 15   https://www.spitishop.gr/100602/πάπλωμα-κούνια...  2.552816
# 31   https://www.spitishop.gr/97799/πάπλωμα-υπέρδιπ...  2.552816
# 36   https://www.spitishop.gr/105821/πάπλωμα-μονό-σ...  2.552816
# 37   https://www.spitishop.gr/230056/πάπλωμα-μονό-p...  2.552816
# 41   https://www.spitishop.gr/127023/πάπλωμα-κούνια...  2.552816
# 56   https://www.spitishop.gr/191553/πάπλωμα-κούνια...  2.552816
# 18   https://www.spitishop.gr/49400/πάπλωμα-μονό-ve...  2.552816
# 19   https://www.spitishop.gr/49401/πάπλωμα-υπέρδιπ...  2.552816
# 34   https://www.spitishop.gr/223879/πάπλωμα-μονό-n...  2.552816
# 38   https://www.spitishop.gr/230057/πάπλωμα-υπέρδι...  2.552816
# 53   https://www.spitishop.gr/190798/πάπλωμα-μάλλιν...  2.552816
# 55   https://www.spitishop.gr/191552/πάπλωμα-κούνια...  2.552816
# 28   https://www.spitishop.gr/43628/πάπλωμα-μονό-an...  2.552816
# 45   https://www.spitishop.gr/160941/πάπλωμα-μονό-σ...  2.552816
# 50   https://www.spitishop.gr/190007/πάπλωμα-κούνια...  2.552816
# ..                                                 ...       ...
# 605  https://www.spitishop.gr/219930/πάπλωμα-σεντόν...  2.010692
# 591  https://www.spitishop.gr/37072/πάπλωμα-φτερό-π...  2.010692
# 597  https://www.spitishop.gr/230024/πάπλωμα-πουπου...  2.010692
# 606  https://www.spitishop.gr/219933/πάπλωμα-σεντόν...  2.010692
# 594  https://www.spitishop.gr/39273/πάπλωμα-φτερό-π...  2.010692
# 607  https://www.spitishop.gr/219936/πάπλωμα-σεντόν...  2.010692
# 613  https://www.spitishop.gr/219963/πάπλωμα-σεντόν...  2.010692
# 600  https://www.spitishop.gr/230035/πάπλωμα-πουπου...  2.010692
# 598  https://www.spitishop.gr/230025/πάπλωμα-πουπου...  2.010692
# 618  https://www.spitishop.gr/243912/πάπλωμα-πουπου...  2.010692
# 612  https://www.spitishop.gr/219960/πάπλωμα-σεντόν...  2.010692
# 599  https://www.spitishop.gr/230036/πάπλωμα-πουπου...  2.010692
# 604  https://www.spitishop.gr/212818/πάπλωμα-κούνια...  2.010692
# 614  https://www.spitishop.gr/221563/πάπλωμα-πουπου...  2.010692
# 602  https://www.spitishop.gr/159618/πάπλωμα-king-s...  2.010692
# 609  https://www.spitishop.gr/219945/πάπλωμα-σεντόν...  2.010692
# 610  https://www.spitishop.gr/219954/πάπλωμα-σεντόν...  2.010692
# 616  https://www.spitishop.gr/242397/πάπλωμα-μάλλιν...  2.010692
# 617  https://www.spitishop.gr/243897/πάπλωμα-πουπου...  2.010692
# 593  https://www.spitishop.gr/39213/πάπλωμα-πουπουλ...  2.010692
# 601  https://www.spitishop.gr/157702/πάπλωμα-4-εποχ...  2.010692
# 615  https://www.spitishop.gr/222092/πάπλωμα-υπέρδι...  2.010692
# 592  https://www.spitishop.gr/39212/πάπλωμα-πουπουλ...  2.010692
# 595  https://www.spitishop.gr/39376/πάπλωμα-μονό-do...  2.010692
# 603  https://www.spitishop.gr/126809/πάπλωμα-κούνια...  2.010692
# 611  https://www.spitishop.gr/219957/πάπλωμα-σεντόν...  2.010692
# 596  https://www.spitishop.gr/97944/πάπλωμα-πουπουλ...  2.010692
# 621  https://www.spitishop.gr/243917/πάπλωμα-πουπου...  1.909324
# 619  https://www.spitishop.gr/149807/πάπλωμα-πουπου...  1.909324
# 620  https://www.spitishop.gr/149808/πάπλωμα-πουπου...  1.909324
#
#                                              title_eng
# 0                            paploma mono nima balance
# 1                       paploma yperdiplo nima balance
# 8                         paploma kounias rythmos hope
# 5                       paploma kounias rythmos flying
# 6                         paploma kounias rythmos malo
# 7                     paploma kounias rythmos elefante
# 2                       paploma kounias viopros patrik
# 3                       paploma kounias viopros antzel
# 4                       paploma kounias rythmos nautic
# 32                    paploma mono nef-nef hollowfiber
# 33               paploma yperdiplo nef-nef hollowfiber
# 30                     paploma mono nef-nef microfiber
# 42                 paploma kounias dimcol aerostato 01
# 57                 paploma kounias rythmos paint spots
# 14                   paploma yperdiplo sb home couette
# 15                    paploma kounias nima baby beetle
# 31                paploma yperdiplo nef-nef microfiber
# 36                     paploma mono (set) viopros 5230
# 37            paploma mono palamaiki stripe microfiber
# 41                       paploma kounias dimcol car 29
# 56                   paploma kounias rythmos tiny pink
# 18                   paploma mono vesta olympus 300gsm
# 19              paploma yperdiplo vesta olympus 300gsm
# 34                        paploma mono nima super soft
# 38       paploma yperdiplo palamaiki stripe microfiber
# 53              paploma mallino yperdiplo rythmos wool
# 55                   paploma kounias rythmos tiny blue
# 28                      paploma mono anna riska luxury
# 45                    paploma mono (set) rythmos score
# 50                paploma kounias rythmos balloon pink
# ..                                                 ...
# 605  paploma + sentonia yperdipla (set) das home wi...
# 591  paploma ftero - poupoulo yperdiplo viopros fea...
# 597  paploma poupoulenio yperdiplo palamaiki 50/50 ...
# 606  paploma + sentonia yperdipla (set) das home wi...
# 594  paploma ftero - poupoulo mono viopros feather ...
# 607  paploma + sentonia yperdipla (set) das home wi...
# 613  paploma + sentonia yperdipla (set) das home wi...
# 600  paploma poupoulenio yperdiplo palamaiki 50/50 ...
# 598  paploma poupoulenio mono palamaiki 50/50 aloe ...
# 618  paploma poupoulenio yperdiplo la luna white du...
# 612  paploma + sentonia yperdipla (set) das home wi...
# 599  paploma poupoulenio mono palamaiki 50/50 aloe ...
# 604          paploma kounias nef-nef a day at the park
# 614  paploma poupoulenio king size polo club premiu...
# 602  paploma king size 4 epoxwn palamaiki twin stri...
# 609  paploma + sentonia mona (set) das home winter ...
# 610  paploma + sentonia mona (set) das home winter ...
# 616  paploma mallino king size la luna wool natural...
# 617  paploma poupoulenio mono la luna white duvet 8...
# 593  paploma poupoulenio yperdiplo anna riska 4 epo...
# 601  paploma 4 epoxwn king size kentia accessories ...
# 615  paploma yperdiplo 2 opseon nima bed linen abal...
# 592  paploma poupoulenio mono anna riska 4 epoxwn 9...
# 595    paploma mono down town damas salmon primo s 426
# 603  paploma kounias kosmos tou morou 7959 hard day...
# 611  paploma + sentonia mona (set) das home winter ...
# 596  paploma poupoulenio mono nef-nef white goose d...
# 621  paploma poupoulenio king size la luna white du...
# 619  paploma poupoulenio mono nef-nef white duck do...
# 620  paploma poupoulenio yperdiplo nef-nef white du...
#
# [622 rows x 9 columns]

# %%
# https://www.elastic.co/guide/en/elasticsearch/reference/current/search-as-you-type.html
